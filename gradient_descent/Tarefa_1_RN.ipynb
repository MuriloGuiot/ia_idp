# %% [markdown]
# # **Objetivo: criar uma rede neural simples usando Keras para uma tarefa de classificação binária**

# %% [markdown]
#  # **Importação dos Dados e Processamento**

# %% [markdown]
# O conjunto de dados que será utilizado aqui é: "**Pima Indians Diabetes Dataset**". Ele pode ser baixado de: https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv
#
# Este é um problema de classificação binária (2 classes). No conjunto de dados existem 768 observações com 8 variáveis de entrada e 1 variável de saída.
#
# Os nomes das variáveis são os seguintes:
#
# **1. Número de vezes grávida.**
#
# **2. Concentração de glicose plasmática após 2 horas em um teste oral de tolerância à glicose.**
#
# **3. Pressão arterial diastólica (mm Hg).**
#
# **4. Espessura da prega cutânea do tríceps (mm).**
#
# **5. Insulina sérica em 2 horas (mu U/ml).**
#
# **6. Índice de massa corporal (peso em kg/(altura em m)^2).**
#
# **7. Função pedigree para diabetes.**
#
# **8. Idade (anos).**
#
# **9. Variável de classe (0 ou 1).**

# %% [markdown]
# ---
# Importe as bibliotecas necessárias

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# Importe e visualize detalhes dos dados usando os comandos `np.loadtext('nome do arquivo', delimiter=',')` e `np.shape(...)`

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('pima_indians_diabetes.csv')
print(df)
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %% [markdown]
# ---
# Crie vetores `X_data` e `Y_data` para separar os 8 features, que são as entradas, e a única saída

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('pima_indians_diabetes.csv')

X_data = df.iloc[:, :-1]

Y_data = df.iloc[:, -1]

print("--- Features (X_data) ---")
print(X_data)

print("\n--- Saída (Y_data) ---")
print(Y_data)
# Out:
# --- Features (X_data) ---
#       6  148  72  35    0  33.6  0.627  50
# 0     1   85  66  29    0  26.6  0.351  31
# 1     8  183  64   0    0  23.3  0.672  32
# 2     1   89  66  23   94  28.1  0.167  21
# 3     0  137  40  35  168  43.1  2.288  33
# 4     5  116  74   0    0  25.6  0.201  30
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 762  10  101  76  48  180  32.9  0.171  63
# 763   2  122  70  27    0  36.8  0.340  27
# 764   5  121  72  23  112  26.2  0.245  30
# 765   1  126  60   0    0  30.1  0.349  47
# 766   1   93  70  31    0  30.4  0.315  23
#
# [767 rows x 8 columns]
#
# --- Saída (Y_data) ---
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 762    0
# 763    0
# 764    0
# 765    1
# 766    0
# Name: 1, Length: 767, dtype: int64

# %% [markdown]
# ---
# Separe os dados de treino e de teste usando o comando `train_test_split()`

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)

print("Primeiras 5 linhas do dataset:")
print(df.head())
print("\nShape do dataset:", df.shape)

X = df.iloc[:, :-1]

Y = df.iloc[:, -1]

print(("\nShape de X (features):"), X.shape)
print(("Shape de Y (target):"), Y.shape)

# 3. Separar os dados de treino e de teste
# test_size=0.2 significa 20% dos dados para teste e 80% para treino
# random_state=42 garante que a separação seja a mesma toda vez
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# 4. Verificar as dimensões dos conjuntos de treino e teste
print("\n--- Dimensões dos conjuntos de treino e teste ---")
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# Primeiras 5 linhas do dataset:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0
#
# Shape do dataset: (767, 9)
#
# Shape de X (features): (767, 8)
# Shape de Y (target): (767,)
#
# --- Dimensões dos conjuntos de treino e teste ---
# X_train shape: (613, 8)
# Y_train shape: (613,)
# X_test shape: (154, 8)
# Y_test shape: (154,)

# %% [markdown]
# ---
# Verifique a dimensão do conjunto de treino e teste

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)

X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("--- Dimensões dos conjuntos de treino e teste ---")
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# --- Dimensões dos conjuntos de treino e teste ---
# X_train shape: (613, 8)
# Y_train shape: (613,)
# X_test shape: (154, 8)
# Y_test shape: (154,)

# %% [markdown]
# # **Construa o Modelo**

# %% [markdown]
# ---
# Crie o seu modelo

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# --- Preparação dos Dados ---
path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# --- Construção e Treinamento do Modelo ---
model = MLPClassifier(
    hidden_layer_sizes=(12, 8),
    activation='relu',
    solver='adam',
    max_iter=1000,
    learning_rate_init=0.001,
    random_state=42
)

print("Iniciando o treinamento...")
model.fit(X_train, Y_train)
print("Treinamento concluído!")

# --- Avaliação e Exibição dos Resultados ---
print("\n--- Avaliação do Modelo ---")

# Fazendo previsões nos dados de teste
Y_pred = model.predict(X_test)

# Calculando a precisão do modelo
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Acurácia do modelo nos dados de teste: {accuracy:.4f}")

# Exibindo um relatório de classificação detalhado
report = classification_report(Y_test, Y_pred)
print("\nRelatório de Classificação:\n", report)

# Exibindo as previsões e os valores reais para as primeiras 10 amostras
print("\nPrimeiras 10 previsões vs. valores reais:")
for i in range(10):
    print(f"Previsão: {Y_pred[i]}, Real: {Y_test.iloc[i]}")
# Out:
# Iniciando o treinamento...
# Treinamento concluído!
#
# --- Avaliação do Modelo ---
# Acurácia do modelo nos dados de teste: 0.6818
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76        97
#            1       0.58      0.51      0.54        57
#
#     accuracy                           0.68       154
#    macro avg       0.66      0.65      0.65       154
# weighted avg       0.67      0.68      0.68       154
#
#
# Primeiras 10 previsões vs. valores reais:
# Previsão: 1, Real: 0
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0
# Previsão: 1, Real: 1
# Previsão: 0, Real: 0
# Previsão: 0, Real: 0

# %% [markdown]
# ---
# Adicione as camadas: lembrando que a primeira camada recebe como entrada um vetor no $\mathbb{R}^8$.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)

X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = MLPClassifier(
    hidden_layer_sizes=(12, 8),
    activation='relu',
    solver='adam',
    max_iter=1000,
    learning_rate_init=0.001,
    random_state=42
)

print("Iniciando o treinamento do modelo...")
model.fit(X_train, Y_train)
print("Treinamento concluído!")

print("\n--- Avaliação do Modelo ---")

Y_pred = model.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print(f"Acurácia do modelo nos dados de teste: {accuracy:.4f}")

report = classification_report(Y_test, Y_pred)
print("\nRelatório de Classificação:\n", report)
# Out:
# Iniciando o treinamento do modelo...
# Treinamento concluído!
#
# --- Avaliação do Modelo ---
# Acurácia do modelo nos dados de teste: 0.6818
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76        97
#            1       0.58      0.51      0.54        57
#
#     accuracy                           0.68       154
#    macro avg       0.66      0.65      0.65       154
# weighted avg       0.67      0.68      0.68       154

# %% [markdown]
# ---
# Compile o modelo escolhendo a função de perda e o otimizador.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# 1. Preparação dos Dados
path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Função de Perda:
# Para a classificação, o MLPClassifier usa a "Cross-Entropy"
# (Entropia Cruzada) por padrão. O Scikit-learn gerencia isso
# internamente, pois é a função de perda mais adequada para este
# tipo de problema. Ela mede quão erradas estão as previsões
# do modelo em relação aos valores reais.

# Otimizador (Gradient Descent):
# O parâmetro 'solver' é onde você escolhe o otimizador.
# 'adam' é uma versão otimizada do Gradiente Descendente.
# Ele ajusta a taxa de aprendizado de forma adaptativa,
# tornando o treinamento mais rápido e robusto.

model = MLPClassifier(
    hidden_layer_sizes=(12, 8),
    activation='relu',
    solver='adam',  # Este é o OTIMIZADOR
    max_iter=1000,
    learning_rate_init=0.001,
    random_state=42
)

# 3. Treinar o Modelo
print("Iniciando o treinamento do modelo...")
model.fit(X_train, Y_train)
print("Treinamento concluído!")

# 4. Avaliar o Modelo
print("\n--- Avaliação do Modelo ---")
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Acurácia do modelo nos dados de teste: {accuracy:.4f}")
report = classification_report(Y_test, Y_pred)
print("\nRelatório de Classificação:\n", report)
# Out:
# Iniciando o treinamento do modelo...
# Treinamento concluído!
#
# --- Avaliação do Modelo ---
# Acurácia do modelo nos dados de teste: 0.6818
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76        97
#            1       0.58      0.51      0.54        57
#
#     accuracy                           0.68       154
#    macro avg       0.66      0.65      0.65       154
# weighted avg       0.67      0.68      0.68       154

# %% [markdown]
# # **Treine e Teste**

# %% [markdown]
# ---
# Avalie a precisão usando o comando `model.evaluate()`

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# 1. Preparação dos Dados
path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# 2. Construção e Treinamento do Modelo
model = MLPClassifier(
    hidden_layer_sizes=(12, 8),
    activation='relu',
    solver='adam',
    max_iter=1000,
    learning_rate_init=0.001,
    random_state=42
)

print("Iniciando o treinamento do modelo...")
model.fit(X_train, Y_train)
print("Treinamento concluído!")

# 3. Avaliar a precisão com model.score()
accuracy = model.score(X_test, Y_test)

print("\n--- Avaliação do Modelo ---")
print(f"A precisão do modelo nos dados de teste é: {accuracy:.4f}")
# Out:
# Iniciando o treinamento do modelo...
# Treinamento concluído!
#
# --- Avaliação do Modelo ---
# A precisão do modelo nos dados de teste é: 0.6818

# %% [markdown]
# Como ficou o resultado? Será que dá pra melhorar?

# %% [markdown]
# ---
# Crie uma pessoa imaginária com um vetor, por exemplo, na forma `np.array([[2,148,72,35,0,33.6,0.627,25]])` e use o comando `model.predict()` para verificar se essa pessoa é classificada com ou sem diabetes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

path = 'pima_indians_diabetes.csv'
df = pd.read_csv(path)
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = MLPClassifier(
    hidden_layer_sizes=(12, 8),
    activation='relu',
    solver='adam',
    max_iter=1000,
    learning_rate_init=0.001,
    random_state=42
)

model.fit(X_train, Y_train)

nova_pessoa = np.array([[2, 148, 72, 35, 0, 33.6, 0.627, 25]])

previsao = model.predict(nova_pessoa)

print(f"Dados de entrada da nova pessoa: {nova_pessoa[0]}")
print(f"Previsão do modelo: {previsao[0]}")

if previsao[0] == 1:
    print("O modelo classifica esta pessoa como tendo diabetes.")
else:
    print("O modelo classifica esta pessoa como não tendo diabetes.")
# Out:
# Dados de entrada da nova pessoa: [  2.    148.     72.     35.      0.     33.6     0.627  25.   ]
# Previsão do modelo: 1
# O modelo classifica esta pessoa como tendo diabetes.
# C:\Users\muckz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

path = 'pima_indiands_diabetes.csv'
df = pd.read_csv(path)
# Substituir NaN pela média das colunas
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Padronizar os dados (recomendado para KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Treinar e avaliar o KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, X_train)
y_pred = knn.predict(X_test_scaled)

print("Acurácia do modelo:", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 from sklearn.metrics import accuracy_score
#       6 path = 'pima_indiands_diabetes.csv'
# ----> 7 df = pd.read_csv(path)
#       8 # Substituir NaN pela média das colunas
#       9 imputer = SimpleImputer(strategy='mean')
#
# ...
