# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
#Importar Dataset
ruta = 'Diabetes_Dataset_Missing_Data.xlsx'
diabetes_dataset = pd.read_excel(ruta)

# visualizar primeiras linhas
print(diabetes_dataset.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1        0             48            NaN      0.0  24.7
# 1            1        0             74            NaN     23.0  27.7
# 2            1        0             68           35.0      0.0  32.0
# 3            5        0             80           32.0      0.0  41.0
# 4            6        0             68           41.0      0.0  39.0
#
#    familyHistoryDiabetes  Age  Outcome
# 0                  0.140   22        0
# 1                  0.299   21        0
# 2                  0.389   22        0
# 3                  0.346   37        1
# 4                  0.727   41        1

# %%
#Selecionar as variáveis ​​preditoras e a variável de resposta
X = diabetes_dataset[['Glucose','Age','BMI','familyHistoryDiabetes']]
y = diabetes_dataset['Outcome']

#Dividir em conjunto de treinamento e conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.3)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Substituir NaN pela média das colunas
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Padronizar os dados (recomendado para KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Treinar e avaliar o KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)

print("Acurácia do modelo:", accuracy_score(y_test, y_pred))
# Out:
# Acurácia do modelo: 0.70995670995671
